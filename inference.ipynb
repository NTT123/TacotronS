# %%
# download a pre-trained model
# !gdown --id 1EDvxoS7AobSXUiKDMmFIl2dkpyKopvhh -O model.ckpt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EDvxoS7AobSXUiKDMmFIl2dkpyKopvhh
# To: /workspaces/TacotronS/model.ckpt
# 100%|█████████████████████████████████████████| 201M/201M [00:01<00:00, 198MB/s]

# %%
# !python inference.py -a tf_data/alphabet.txt  -m model.ckpt -o mel -t "But she had never felt so strongly as now the disadvantages which must attend the children of so unsuitable a marriage, nor ever been so fully aware of the evils arising from so ill-judged a direction of talents; talents, which, rightly used, might at least have preserved the respectability of his daughters, even if incapable of enlarging the mind of his wife."
# Out:
# Input:  but she had never felt so strongly as now the disadvantages which must attend the children of so unsuitable a marriage, nor ever been so fully aware of the evils arising from so ill-judged a direction of talents; talents, which, rightly used, might at least have preserved the respectability of his daughters, even if incapable of enlarging the mind of his wife.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

mel = np.load("mel.npy")
plt.figure(figsize=(25, 2))
plt.imshow(mel[0].T, origin="lower", aspect="auto")
